# %% [markdown]
# # URLShortener: A SysML 2.0
#
# This notebook provides a simple example of SysML 2.0. Additional examples from the SysML v2 source can be found [here](https://github.com/Systems-Modeling/SysML-v2-Release/tree/master/sysml/src/examples) along with documentation and training resources.

# %%
package MyModel {
    public import UrlShortenerService::*;
}
# Out:
# Package MyModel (01265274-4a7a-4a63-b422-18e12000dd5f)

# %%
%viz --style PLANTUML UrlShortenerService

# %%
%viz --view INTERCONNECTION --style PLANTUML UrlShortenerService::context
